# %%
# !pip install python-docx pandas numpy
# Out:
# ������� ������� ��������: 1251
# ...

# %%
import xml.etree.ElementTree as ET
import zipfile
from docx import Document
import os
import re
import sys
import traceback
import psycopg2
import uuid
import logging
import pandas as pd
import numpy as np

# %%
docx_path = r'.\15_ДСиР-2022-864-Р-8.1.2-СО.docx'
output_folder = r'.\TestDocToXml'

# %%
xml_path = output_folder + r'\word\footer3.xml'
tree = ET.parse(xml_path)

# Получение корневого элемента
root = tree.getroot()
namespaces = {'w': 'http://schemas.openxmlformats.org/wordprocessingml/2006/main'}
elements = root.findall('.//w:t', namespaces)

f=0
for elem in elements:
    if elem.text.startswith('ДСиР'):
        f=1
    if f and f<5:
        f += 1
        print(elem.text)
# Out:
# ДСиР-2022-864-Р-8.1.
# 2
# -СО
# «Строительство скоростной автомобильной дороги Москва – Санкт-Петербург
# ДСиР-2022-864-Р-8.1.
# 2
# -СО
# «Строительство скоростной автомобильной дороги Москва – Санкт-Петербург

# %%
df = pd.read_xml(xml_path)
df
# Out:
#      paraId    textId     rsidR   rsidRPr rsidRDefault     rsidP  pPr   r
# 0  1D66B76B  1AB98EE4  00FC69C5  00717C65     00FC69C5  00717C65  NaN NaN

# %%
# Out:
#   0      1                                                  2   \
# 4         1          Линейные сооружения кабельных линий связи
# 5       1.1              Кабельная канализация в грунте. Трубы
# 6     1.1.1  Труба двустенная ПНД гибкая для кабельной кана...
# 7     1.1.2                     Заглушка для трубы ПНД, d=63мм
# 8     1.1.3                             Лента сигнальная 450мм
# 9       1.2            Кабельная канализация в грунте. Колодцы
#
#                          3                         4             5   \
# 4
# 5
# 6  ГОСТ Р МЭК 61386.24-2014  ГОСТ Р МЭК 61386.24-2014       121963A
# 7                                                            023063
# 8                                                      120808-00024
# 9
#
#              6                       7                       8    9    10  11  \
# 4
# 5
# 6       121963A                  «ДКС»                   «ДКС»     м    м  16
# ...
